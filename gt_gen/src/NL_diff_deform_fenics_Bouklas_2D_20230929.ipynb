# %% [markdown]
# # Diffusion-deformation theories for hydrogels
#
# Author: Jorge Urrea - 2024.01.17
#
# ## Introduction
#
# We solve the transient nonlinear chemoelastic problem presented by Bouklas et al. (2015) using Fenics. This model describes the swelling kinetics of polymer gels. In this model both fields are fully coupled and it is assumed that the evolution is quasi-static, thus, the inertial effects are neglected. A staggered approach is adopted.

# %%
from dolfin import *
from mshr import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Model setup
L = 0.01  # length of the plate
N = 10  # mesh density

mesh = UnitSquareMesh(N,N)

# Scale the mesh to the desired domain size
coordinates = mesh.coordinates()
for coord in coordinates:
    coord *= L

# %%
#Defining the model parameters
µ_o = -0.3124#-6 # initial chemical potential
µ_dry = -1.897 # chemical potential when material is dry
µ_swell = -0.00 # chemical potential when material is swollen and in equilibrium

µ_diff = -0.001#0.0 # chemical potential difference (µ - µ_o) (µ = µ_swell when gel is swollen)

# %%
# Form compiler options
parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True

# %%
### Field variable function spaces
element_u = VectorElement('CG', mesh.ufl_cell(), 2) # displacement finite element
element_mu = FiniteElement('CG', mesh.ufl_cell(), 1) # chemical potential finite element
element_Jac = FiniteElement('CG', mesh.ufl_cell(), 1)
V, Q, P = FunctionSpace(mesh, element_u), FunctionSpace(mesh, element_mu), FunctionSpace(mesh, element_Jac)

# %%
# Define boundary conditions
class Left(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[0], 0)
class Right(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[0], L)
class Top(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[1], L)
class Bottom(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[1], 0)

# Add boundaries
left = Left()
right = Right()
top = Top()
bottom = Bottom()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim()-1, 0)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
top.mark(boundaries,3)
bottom.mark(boundaries,4)

# %%
# zero displacement boundary conditions on the symmetric part of the plate
u_bc_bottom = DirichletBC(V.sub(1), Constant(0.0), bottom) 
u_bc_right = DirichletBC(V.sub(0), Constant(0.0), right)
u_bc_left = DirichletBC(V.sub(0), Constant(0.0), left)

# chemical potential on the outer boundaries
mu_bc_top = DirichletBC(Q, Constant(µ_swell), top)
# mu_bc_left = DirichletBC(Q, Constant(µ_diff), left)
mu_bc_right = DirichletBC(Q, Constant(µ_swell), right)

# Jacobian BCs
Jacb_bc_top = DirichletBC(P, Constant(4.2), top)
# mu_bc_left = DirichletBC(Q, Constant(µ_diff), left)
Jacb_bc_right = DirichletBC(P, Constant(4.2), right)

# bcs = [u_bc_bottom, u_bc_right, mu_bc_bottom, mu_bc_right]
# bcs = [u_bc_bottom, u_bc_right, mu_bc_top, mu_bc_left]

bc_u = [u_bc_bottom, u_bc_left]#, u_bc_right]
bc_mu = [mu_bc_top, mu_bc_right] #mu_bc_left]
# bc_Jacb = [Jacb_bc_top, Jacb_bc_right]

# %%
(du, dµ, dJacb) = TrialFunction(V), TrialFunction(Q), TrialFunction(P)
(v, q, p) = TestFunction(V), TestFunction(Q), TestFunction(P)

(u, µ, Jacb) = Function(V), Function(Q), Function(P)
(uold, µold, Jacb_old) = Function(V), Function(Q), Function(P)

# Create intial conditions and interpolate
# u_init = InitialConditions()
Jacb_init = Expression("1.4", degree=1)
Jacb_old.interpolate(Jacb_init)
Jacb.assign(Jacb_old)

u_init = Expression("-0.035", degree=1)#-0.3124 #-5.71
µold.interpolate(u_init)
µ.assign(µold)

# %% [markdown]
# Kinematic quantities

# %%
# Model parameters
# Elasticity parameters
G0, χ = Constant(1.7e7), Constant(0.4) # <= Bouklas et al.
# G0, χ = Constant(1e7), Constant(0.2) # <= Liu et al.
K = Constant(100*41143.3342)#Constant(10*41143.3342)
NΩ = Constant(1e-3)#Constant(1e-3)#
Ω = Constant(1.7e-28)                          # the volume per solvent molecule
kBT = Constant(1.3806488e-23*298)              # T = 298 K
NkBT = Constant(1e25*1.3806488e-23*298)
D = Constant(2e-3)#Constant(7.4e-11)                          # species diffusivity m^2 s^-1
mc = Constant(0.1)

print(1e25*1.3806488e-23*298)
print(-0.035*1.3806488e-23*298)
# Out:
# 41143.334240000004
# -1.4400166984000003e-22

# %%
# Kinematics
d = u.geometric_dimension()
I = Identity(d)                         # Identity tensor

def F(u):
    return variable(I + grad(u)) 

# F = variable(I + grad(u))               # Deformation gradient

# Right Cauchy-Green tensor
def C(u):
    return variable(F(u).T*F(u))
# C = F.T*F     
# 
# Green Lagrange strain tenson
def E(u):
    return variable(grad(u).T + grad(u) + grad(u).T*grad(u))
    # return variable(0.5*(F(u).T*F(u) - I))                        

# Left Cauchy-Green tensor
def B(u):
    return variable(F(u)*F(u).T)

# Invariants of deformation tensors
def Ic(u):
    return variable(tr(F(u).T*F(u)))
 
# Ic = tr(F(u).T*F(u))

def J(u):
    return variable(det(F(u)))

# J  = (det(F)) #1 + Ω*C

# %%
def psi_chem(Jacb):
    return variable((1/NΩ)*((Jacb-1)*ln(Jacb/(1 - Jacb)) + χ/Jacb))

def S_(u,Jacb,µ):
    return variable(NkBT*(F(u) + (-(1/J(u)) + (K/NkBT)*(J(u) - kBT*Jacb))*J(u)*inv(F(u).T))*(F(u).T))

def PK1(u,Jacb,µ):
    return variable(J(u)*S_(u,Jacb,µ)*inv(F(u).T))

def µ_(u,Jacb):
    return variable(ln((Jacb - 0.999)/Jacb) + (Jacb + χ)/(0.999*Jacb**2) + (Ω*K/kBT)*(det(F(u)) - Jacb))

# %%
# Elasticity parameters
# E, nu = 70e3, 0.3
# mu, lmbda = Constant(E/(2*(1 + nu))), Constant(E*nu/((1 + nu)*(1 - 2*nu)))
# Stored strain energy density (compressible neo-Hookean model + chem potential)
def psi(u,µ,Jacb):
    return variable((1/2)*(Ic(u) - 3 - 2*ln(0.999*J(u))) + (K/(2*NkBT))*(det(F(u)) - Jacb)**2)

# %%
ds = Measure('ds', domain=mesh, subdomain_data=boundaries)

dt = Constant(0.)

# Total potential energy
Psi_n = psi(u,µ,Jacb)*dx# - inner(T, u)*ds
Pi_mech_n = derivative(Psi_n, u, v) 

Jac_n = derivative(Pi_mech_n, u, du) 

# Jacobian implicit equation (for instance concentration)
Pi_Jacb = (-µ + ln((Jacb - 0.999)/Jacb) + (Jacb + χ)/(0.999*Jacb**2) - (Ω*K/kBT)*(det(F(u)) - Jacb))*p*dx

JacJ_n = derivative(Pi_Jacb, Jacb, dJacb)# + derivative(Pi_chem, µ, dµ)

# Mass balance
D = 2.5e-3*kBT # <= Original value that matches the 1D solution
def mr(u,Jacb):
    return variable((Jacb - 0.999)*(D/kBT)*inv(B(u)))

alpha_r = 5000.0 # Robin Boundary constant
Pi_chem = (
            (Jacb - Jacb_old)*q*dx
            + dt*inner(mr(u,Jacb)*grad(µ),grad(q))*dx)
            
Jacmu_n = derivative(Pi_chem, µ, dµ)

# %%
# 1D NL PDE for lambda - incompressibility constraint lifted

mesh_lambda = UnitIntervalMesh(50)

element_lambda = FiniteElement('CG', mesh_lambda.ufl_cell(), 2)
P = FunctionSpace(mesh_lambda, element_lambda)

lambda_o = 1.0 # initial chemical potential

dlambda = TrialFunction(P)
p = TestFunction(P)

lamda = Function(P)
lamda_old = Function(P)

# Create initial condition
lamda0 = 1.4
lambda_init = Expression("1.4", degree=1)
lamda_old.interpolate(lambda_init)
lamda.assign(lamda_old)

# BCs
lambda_right = 4.35#4.25
lambda_bc_left = DirichletBC(P, Constant(0.0), left)
labmda_bc_right = DirichletBC(P, Constant(lambda_right), right)

bc_lambda = labmda_bc_right

def gama(lamda):
    return variable( (lamda0**2) + ((NkBT)/(K*(lamda0**2)))*(1  + 1/(lamda**2)) )

def zeta(lamda):
    return variable( (( 1/ (((lamda0**2)*lamda)**2)) - (2*χ*((lamda0**2)*lamda - 1))/((((lamda0**2)*lamda)**3)))
                    * ( (NkBT*(1 + (lamda**2))/(K*(lamda0**2)*(lamda**4))) + ((lamda0**2)/(lamda**2)) )
                     + NΩ*(((lamda0**2)*lamda - 1)*(lamda**2 + 1))/((lamda0**2)*(lamda**4)))

lambda_form = (gama(lamda)*(lamda - lamda_old)/dt*p
              + dot((2.5e2)*(zeta(lamda))*grad(lamda), grad(p)))*dx
Jac_lambda = derivative(lambda_form, lamda, dlambda)

plt.figure()
# p = plot(u, mode="displacement")
plot(mesh_lambda, linewidth=0.7)
# plt.colorbar(p)
plt.show()

# %%
# Time-stepping
Nincr = 10
t = np.linspace(0, 10, Nincr+1)
Nx = 10
x = np.linspace(0, L, Nx)
µ_res = np.zeros((Nx, Nincr+1))
Jacb_res = np.zeros((Nx, Nincr+1))

lambda_res = np.zeros((Nx, Nincr+1))
syy_array = np.zeros((Nx, Nincr+1))

Jx_array = np.zeros((Nx, Nincr+1))

lambda0_array = np.zeros((Nx, Nincr+1))
lambdaL_array = np.zeros((Nx, Nincr+1))

PK1xx0_array = np.zeros((Nx, Nincr+1))
PK1xxL_array = np.zeros((Nx, Nincr+1))

for (i, dti) in enumerate(np.diff(t)):
    print("Increment " + str(i+1))
    t_current = t[i+1]
    print("t =", t_current) 
    dt.assign(dti)
    
    # Compute tentative displacement step
    begin("Computing tentative displacement")
    solve(Pi_mech_n == 0, u, bc_u, J=Jac_n)#, solver_parameters={"newton_solver":
                                        # {"linear_solver": "gmres", "preconditioner": "ilu"}})#, "relative_tolerance": 1e-6, 
                                        # "convergence_criterion": "incremental", "relaxation_parameter": 0.7}})
    uold.assign(u)
    end()

    # Jacobian
    begin("Computing Jacobian")
    solve(Pi_Jacb == 0, Jacb)#, bc_Jacb)#, J = JacJ_n)
    # solve(lhs(Pi_chem) == rhs(Pi_chem), Jacb, bc_Jacb)#, 
        # solver_parameters={'linear_solver': 'gmres',
        #                  'preconditioner': 'ilu'})
    Jacb_res[:, i+1] = [Jacb(L/2, xi) for xi in x]
    end()

    # Chemical potential
    begin("Computing chemical potential")
    solve(Pi_chem == 0, µ, bc_mu, J = Jacmu_n)#, 
        # solver_parameters={'linear_solver': 'gmres',
        #                  'preconditioner': 'ilu'})
    Jacb_old.assign(Jacb)
    µold.assign(µ)
    µ_res[:, i+1] = [µ(L/2, xi) for xi in x]
    print(µ_res[:, i+1])
    end()

    s_yy = S_(u,Jacb,µ)[1,1]
    syy_P1 = project(s_yy, Q)
    syy_array[:, i+1] = [syy_P1(L/2, xi) for xi in x]  


    Jx0 = J(u)**(1/2)
    Jx0_P1 = project(Jx0, Q)
    Jx_array[:, i+1] = [Jx0_P1(L/2, xi) for xi in x] 
    lambda0_array[:, i+1] = [Jx0_P1(0.0, xi) for xi in x]
    lambdaL_array[:, i+1] = [Jx0_P1(L, xi) for xi in x]  

    PK1xx = PK1(u,Jacb,µ)[0,0]
    PK1xx_P1 = project(PK1xx, Q)
    PK1xx0_array[:, i+1] = [PK1xx_P1(0.0, xi) for xi in x] 
    PK1xxL_array[:, i+1] = [PK1xx_P1(L, xi) for xi in x] 
    

    begin("Computing 1D lambda sol")
    solve(lambda_form == 0, lamda, bc_lambda, J=Jac_lambda)#, 
        # solver_parameters={'linear_solver': 'gmres',
        #                  'preconditioner': 'ilu'})
    lamda_old.assign(lamda)
    lambda_res[:, i+1] = [lamda(xi) for xi in x]
    end()

    # # Plot solution
    plt.figure(figsize=(6,5))
    p = plot(u, mode="displacement")
    plt.xlim((-0.0005, 0.020))
    plt.ylim((-0.0005, 0.020))
    # plt.axvline(x = 0.5, color = 'k', linestyle = '--', label = 'axvline - full height')
    plot(mesh, linewidth=1.0)
    # cbar = plt.colorbar(p)#, shrink = 0.5)
    # cbar.ax.tick_params(labelsize=14)
    plt.tick_params(axis='both', labelsize=16)
    plt.xlabel("$X$-coord. [m]", fontsize=16)
    plt.ylabel("$Y$-coord. [m]", fontsize=16)
    # plt.legend(["deformed gel"])
    plt.title("deformed gel ($t = {:.1f}$ [s])".format(t_current), fontsize = 14)
    # plt.savefig('results/Bouklas/time/Fig_2DFEM_def_gel_x001_{:.1f}.pdf'.format(t_current))
    plt.close()

    plt.figure(figsize=(6,5))
    p = plot(J(u)**(1/2))
    cbar = plt.colorbar(p)#, shrink = 0.5)
    cbar.ax.tick_params(labelsize=14)
    plt.tick_params(axis='both', labelsize=16)
    plt.xlabel("$X$-coordinate", fontsize=16)
    plt.ylabel("$Y$-coordinate", fontsize=16)
    plt.title("stretch $\lambda$", fontsize = 18)
    # plt.savefig('results/Bouklas/Fig_2DFEM_stretch_{:.1f}.pdf'.format(t_current))
    plt.close()

    plt.figure()
    p = plot(µ)
    plt.colorbar(p)
    plt.close()

    plt.figure()
    p = plot(S_(u,Jacb,µ)[1,1], title="$S_{yy}/NK_{B}T$ normalized nominal stress")
    plt.colorbar(p)
    plt.close() 


    plt.figure(figsize=(6,5))
    p = plot(PK1(u,Jacb,µ)[0,0], title="$PK1_{xx}/Nk_{B}T$ normalized nominal stress")
    cbar = plt.colorbar(p)#, shrink = 0.5)
    cbar.ax.tick_params(labelsize=14)
    plt.tick_params(axis='both', labelsize=16)
    plt.xlabel("$X$-coordinate", fontsize=16)
    plt.ylabel("$Y$-coordinate", fontsize=16)
    plt.title("normalized stress $PK1_{xx}/Nk_B T$", fontsize = 18)
    # plt.savefig('results/Bouklas/Fig_2DFEM_stress_{:.1f}.pdf'.format(t_current))
    plt.close()

    plt.figure(figsize=(6,5))
    p = plot(PK1(u,Jacb,µ)[1,1], title="$PK1_{yy}/Nk_{B}T$ normalized nominal stress")
    cbar = plt.colorbar(p)#, shrink = 0.5)
    cbar.ax.tick_params(labelsize=14)
    plt.tick_params(axis='both', labelsize=16)
    plt.xlabel("$X$-coordinate", fontsize=16)
    plt.ylabel("$Y$-coordinate", fontsize=16)
    plt.title("normalized stress $PK1_{yy}/Nk_B T$", fontsize = 18)
    # plt.savefig('results/Liu/Fig_2DFEM_stress_{:.1f}.pdf'.format(t_current))
    plt.close()

    plt.figure(figsize=(6,5))
    p = plot(PK1(u,Jacb,µ)[1,0], title="$PK1_{xy}/Nk_{B}T$ normalized nominal shear stress")
    cbar = plt.colorbar(p)#, shrink = 0.5)
    cbar.ax.tick_params(labelsize=14)
    plt.tick_params(axis='both', labelsize=16)
    plt.xlabel("$X$-coordinate", fontsize=16)
    plt.ylabel("$Y$-coordinate", fontsize=16)
    plt.title("normalized stress $PK1_{xy}/Nk_B T$", fontsize = 18)
    # plt.savefig('results/Bouklas/Fig_2DFEM_stress_{:.1f}.pdf'.format(t_current))
    plt.close() 

    print("t =", dti)
# Out:
# Increment 1
# t = 1.0
# Computing tentative displacement
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.327e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 6.549e-02 (tol = 1.000e-10) r (rel) = 4.937e-01 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 4.416e-03 (tol = 1.000e-10) r (rel) = 3.328e-02 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.583e-05 (tol = 1.000e-10) r (rel) = 1.947e-04 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 9.028e-10 (tol = 1.000e-10) r (rel) = 6.805e-09 (tol = 1.000e-09)
#     Newton iteration 5: r (abs) = 1.217e-15 (tol = 1.000e-10) r (rel) = 9.171e-15 (tol = 1.000e-09)
#     Newton solver finished in 5 iterations and 5 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 2.808e-06 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 8.941e-07 (tol = 1.000e-10) r (rel) = 3.185e-01 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 1.346e-07 (tol = 1.000e-10) r (rel) = 4.795e-02 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 3.527e-09 (tol = 1.000e-10) r (rel) = 1.256e-03 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 2.473e-12 (tol = 1.000e-10) r (rel) = 8.807e-07 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing chemical potential
# [-6.89442798e-03 -6.82074659e-03 -6.60958152e-03 -6.25400547e-03
#  -5.74221293e-03 -5.05690806e-03 -4.17453677e-03 -3.06443774e-03
#  -1.68821469e-03 -1.55848545e-18]
#   Solving nonlinear variational problem.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#     Newton iteration 0: r (abs) = 4.537e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 2.720e-19 (tol = 1.000e-10) r (rel) = 5.996e-19 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Computing 1D lambda sol
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 2
# t = 2.0
# Computing tentative displacement
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.831e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 6.961e-02 (tol = 1.000e-10) r (rel) = 3.802e-01 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.514e-03 (tol = 1.000e-10) r (rel) = 1.920e-02 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 1.080e-05 (tol = 1.000e-10) r (rel) = 5.897e-05 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 1.030e-10 (tol = 1.000e-10) r (rel) = 5.627e-10 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# [-4.85029299e-03 -4.79921839e-03 -4.65289269e-03 -4.40607487e-03
#  -4.04985941e-03 -3.57123953e-03 -2.95256687e-03 -2.17097647e-03
#  -1.19801742e-03 -1.10600509e-18]
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.043e-06 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.618e-07 (tol = 1.000e-10) r (rel) = 1.551e-01 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.795e-09 (tol = 1.000e-10) r (rel) = 3.637e-03 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.057e-12 (tol = 1.000e-10) r (rel) = 1.972e-06 (tol = 1.000e-09)
#     Newton solver finished in 3 iterations and 3 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.341e-06 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 2.566e-20 (tol = 1.000e-10) r (rel) = 1.913e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 3
# t = 3.0
# Computing tentative displacement
# [-3.44567108e-03 -3.40912332e-03 -3.30450512e-03 -3.12826544e-03
#  -2.87433540e-03 -2.53378426e-03 -2.09436562e-03 -1.53997622e-03
#  -8.50162776e-04 -7.85080900e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.678e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 3.058e-02 (tol = 1.000e-10) r (rel) = 1.822e-01 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 5.658e-04 (tol = 1.000e-10) r (rel) = 3.372e-03 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 7.605e-06 (tol = 1.000e-10) r (rel) = 4.532e-05 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 8.301e-09 (tol = 1.000e-10) r (rel) = 4.947e-08 (tol = 1.000e-09)
#     Newton iteration 5: r (abs) = 1.006e-14 (tol = 1.000e-10) r (rel) = 5.998e-14 (tol = 1.000e-09)
#     Newton solver finished in 5 iterations and 5 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 5.846e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 4.010e-08 (tol = 1.000e-10) r (rel) = 6.860e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 1.651e-10 (tol = 1.000e-10) r (rel) = 2.824e-04 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.767e-15 (tol = 1.000e-10) r (rel) = 4.733e-09 (tol = 1.000e-09)
#     Newton solver finished in 3 iterations and 3 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 9.565e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.287e-20 (tol = 1.000e-10) r (rel) = 1.345e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 4
# t = 4.0
# Computing tentative displacement
# [-2.69588507e-03 -2.66713137e-03 -2.58484226e-03 -2.44632414e-03
#  -2.24696248e-03 -1.97994685e-03 -1.63590049e-03 -1.20242336e-03
#  -6.63641543e-04 -6.12879420e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.295e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.279e-02 (tol = 1.000e-10) r (rel) = 9.875e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 9.674e-05 (tol = 1.000e-10) r (rel) = 7.468e-04 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 1.456e-06 (tol = 1.000e-10) r (rel) = 1.124e-05 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 5.078e-11 (tol = 1.000e-10) r (rel) = 3.921e-10 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 4.171e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.538e-08 (tol = 1.000e-10) r (rel) = 3.688e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 1.817e-11 (tol = 1.000e-10) r (rel) = 4.355e-05 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 5.217e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 9.835e-21 (tol = 1.000e-10) r (rel) = 1.885e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 5
# t = 5.0
# Computing tentative displacement
# [-2.21905379e-03 -2.19532522e-03 -2.12742233e-03 -2.01315910e-03
#  -1.84878684e-03 -1.62876656e-03 -1.34545991e-03 -9.88743412e-04
#  -5.45617547e-04 -5.03893973e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.073e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 7.230e-03 (tol = 1.000e-10) r (rel) = 6.735e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.664e-05 (tol = 1.000e-10) r (rel) = 3.413e-04 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.760e-07 (tol = 1.000e-10) r (rel) = 2.572e-06 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 1.055e-12 (tol = 1.000e-10) r (rel) = 9.827e-12 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 3.285e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 7.395e-09 (tol = 1.000e-10) r (rel) = 2.251e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.294e-12 (tol = 1.000e-10) r (rel) = 1.003e-05 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 3.353e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 7.226e-21 (tol = 1.000e-10) r (rel) = 2.155e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 6
# t = 6.0
# Computing tentative displacement
# [-1.89113945e-03 -1.87088714e-03 -1.81293350e-03 -1.71543059e-03
#  -1.57520787e-03 -1.38757782e-03 -1.14607134e-03 -8.42105431e-04
#  -4.64642554e-04 -4.29114157e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 9.273e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 4.700e-03 (tol = 1.000e-10) r (rel) = 5.068e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 1.092e-05 (tol = 1.000e-10) r (rel) = 1.178e-04 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.187e-08 (tol = 1.000e-10) r (rel) = 2.359e-07 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 1.186e-14 (tol = 1.000e-10) r (rel) = 1.279e-13 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 2.734e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 4.104e-09 (tol = 1.000e-10) r (rel) = 1.501e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 8.246e-13 (tol = 1.000e-10) r (rel) = 3.017e-06 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 2.333e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 5.451e-21 (tol = 1.000e-10) r (rel) = 2.337e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 7
# t = 7.0
# Computing tentative displacement
# [-1.65169569e-03 -1.63399144e-03 -1.58332953e-03 -1.49810387e-03
#  -1.37555810e-03 -1.21161581e-03 -1.00064904e-03 -7.35186712e-04
#  -4.05614095e-04 -3.74599889e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 8.227e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 3.337e-03 (tol = 1.000e-10) r (rel) = 4.057e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 4.737e-06 (tol = 1.000e-10) r (rel) = 5.758e-05 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 1.569e-09 (tol = 1.000e-10) r (rel) = 1.907e-08 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 9.869e-15 (tol = 1.000e-10) r (rel) = 1.200e-13 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 2.355e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 2.512e-09 (tol = 1.000e-10) r (rel) = 1.066e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 2.578e-13 (tol = 1.000e-10) r (rel) = 1.095e-06 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.721e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 4.718e-21 (tol = 1.000e-10) r (rel) = 2.742e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 8
# t = 8.0
# [-1.46902123e-03 -1.45326573e-03 -1.40818012e-03 -1.33234037e-03
#  -1.22330223e-03 -1.07745026e-03 -8.89791852e-04 -6.53697568e-04
#  -3.60632536e-04 -3.33057556e-19]
# Computing tentative displacement
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 7.435e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 2.510e-03 (tol = 1.000e-10) r (rel) = 3.376e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 2.520e-06 (tol = 1.000e-10) r (rel) = 3.390e-05 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.602e-10 (tol = 1.000e-10) r (rel) = 3.500e-09 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 1.045e-14 (tol = 1.000e-10) r (rel) = 1.405e-13 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 2.078e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.649e-09 (tol = 1.000e-10) r (rel) = 7.938e-03 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 9.483e-14 (tol = 1.000e-10) r (rel) = 4.564e-07 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.325e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 4.097e-21 (tol = 1.000e-10) r (rel) = 3.092e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 9
# t = 9.0
# Computing tentative displacement
# [-1.32490360e-03 -1.31068812e-03 -1.27000909e-03 -1.20158481e-03
#  -1.10321516e-03 -9.71645540e-04 -8.02381161e-04 -5.89452831e-04
#  -3.25174297e-04 -3.00310095e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 6.811e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.966e-03 (tol = 1.000e-10) r (rel) = 2.886e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.505e-06 (tol = 1.000e-10) r (rel) = 5.145e-05 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 2.209e-09 (tol = 1.000e-10) r (rel) = 3.243e-08 (tol = 1.000e-09)
#     Newton iteration 4: r (abs) = 1.214e-14 (tol = 1.000e-10) r (rel) = 1.782e-13 (tol = 1.000e-09)
#     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.865e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.142e-09 (tol = 1.000e-10) r (rel) = 6.125e-03 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 3.946e-14 (tol = 1.000e-10) r (rel) = 2.116e-07 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.054e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 3.670e-21 (tol = 1.000e-10) r (rel) = 3.480e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0
# Increment 10
# t = 10.0
# Computing tentative displacement
# [-1.20816622e-03 -1.19519969e-03 -1.15809423e-03 -1.09568274e-03
#  -1.00596164e-03 -8.85966987e-04 -7.31605238e-04 -5.37439810e-04
#  -2.96469812e-04 -2.73799921e-19]
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 6.305e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 1.589e-03 (tol = 1.000e-10) r (rel) = 2.520e-02 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 9.232e-07 (tol = 1.000e-10) r (rel) = 1.464e-05 (tol = 1.000e-09)
#     Newton iteration 3: r (abs) = 3.718e-13 (tol = 1.000e-10) r (rel) = 5.897e-12 (tol = 1.000e-09)
#     Newton solver finished in 3 iterations and 3 linear solver iterations.
# Computing Jacobian
#   No Jacobian form specified for nonlinear variational problem.
#   Differentiating residual form F to obtain Jacobian J = F'.
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 1.696e-07 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 8.244e-10 (tol = 1.000e-10) r (rel) = 4.862e-03 (tol = 1.000e-09)
#     Newton iteration 2: r (abs) = 1.809e-14 (tol = 1.000e-10) r (rel) = 1.067e-07 (tol = 1.000e-09)
#     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Computing chemical potential
#   Solving nonlinear variational problem.
#     Newton iteration 0: r (abs) = 8.606e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton iteration 1: r (abs) = 3.443e-21 (tol = 1.000e-10) r (rel) = 4.000e-14 (tol = 1.000e-09)
#     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Computing 1D lambda sol
#   Solving nonlinear variational problem.
#     *** Warning: Found no facets matching domain for boundary condition.
#     Newton iteration 0: r (abs) = 2.861e-12 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# Object cannot be plotted directly, projecting to piecewise linears.
# t = 1.0

# %%
plt.figure()
p = plot(u, mode="displacement")
plot(mesh, linewidth=0.7)
plt.colorbar(p)
plt.show()

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1 import make_axes_locatable
from labellines import labelLine, labelLines

# stretch
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[0]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

for n in [0,2,4,9]:
    # ax.plot(x, lambda_res[:, n+1], 'k.')
    ax.plot(x, Jx_array[:, n+1], color=colormap(normalize(n)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))


labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=12)
ax.set_xlabel("$Y$-coord. along $X=0.005$ [m]", fontsize=16)
ax.set_ylabel("stretch $\lambda$", fontsize=16)
# ax.legend(["reference 1D sol.", "2D FEM approx."], fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda Jx_array, pos: "{:.2f}".format(Jx_array)))

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Bouklas/Fig_2DFEM_lambda_Bouklas_x001.pdf')

# stretch
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[1]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

print(lambda0_array.size)

ax.plot(t[1:], lambda0_array[0, 1:], color=colormap(normalize(0)), label="a")
ax.plot(t[1:], lambda0_array[-1, 1:], color=colormap(normalize(3)), label="b")
ax.plot(t[1:], lambdaL_array[-1, 1:], color=colormap(normalize(7)), label="c")

xvals = [0.2, 0.2, 0.2]
labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=12)
ax.set_xlabel("time [s]", fontsize=16)
ax.set_ylabel("$\lambda$ at different corners", fontsize=16)
# ax.legend(["bottom-left edge", "bottom-right edge", "top-left edge"], fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=14)

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Bouklas/Fig_2DFEM_stretch_Bouklas_x001.pdf')

# stress
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[2]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

print(PK1xxL_array.size)

ax.plot(t[1:], PK1xx0_array[0, 1:], color=colormap(normalize(0)), label="a")
ax.plot(t[1:], PK1xx0_array[-1, 1:], color=colormap(normalize(7)), label="b")
ax.plot(t[1:], PK1xxL_array[-1, 1:], color=colormap(normalize(3)), label="c")

xvals = [0.2, 0.2, 0.2]
labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=12)
ax.set_xlabel("time [s]", fontsize=16)
# ax.set_ylabel("normalized stress at different edges \n $PK1_{xx}/Nk_B T$ [MPa/MPa]", fontsize=14)
ax.set_ylabel("compressive stress \n $PK1_{xx}$ [Pa]", fontsize=16)
# ax.legend(["reference 1D sol.", "2D FEM approx."])
ax.tick_params(axis='both', which='major', labelsize=14)

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Bouklas/Fig_2DFEM_PK1_Bouklas_x001.pdf')
plt.show()

# chemical potential
fig, ax = plt.subplots()
# ax = axes[2]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

for n in nValues:
    ax.plot(x, µ_res[:, n+1], color=colormap(normalize(n)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))

labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=8)
ax.set_xlabel("$Y$-coordinate along $X=1.0$", fontsize=14)
ax.set_ylabel("normalized chemical potential \n $\mu/k_B T$ [mol$^{-1}$]", fontsize=14)
# ax.legend(["reference 1D sol.", "2D FEM approx."])
ax.tick_params(axis='both', which='major', labelsize=14)
# Out:
# 110
# 110
