# %% [markdown]
# # Diffusion-deformation theories for hydrogels
#
# Author: Jorge Urrea - 2024.01.17
#
# ## Introduction
#
# We solve the transient nonlinear chemoelastic problem presented by Chester et al. (2011,2015) using Fenics. This model describes the swelling kinetics of polymer gels. In this model both fields are fully coupled and it is assumed that the evolution is quasi-static, thus, the inertial effects are neglected. A staggered approach is adopted.

# %%
from dolfin import *
from mshr import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Model setup
L = 0.01  # length of the plate
N = 25  # mesh density <= Chester et al. 2010 - 2011

W = 0.08  # width
H = 0.01  # height
nx = 20   # number of cells along x
ny = 10   # number of cells along y
# data = np.load('/home/fenics/shared/dataset/warmup/uniaxial_swell_data.npz', allow_pickle=True)
# u_last = data['u_time_series'][-1]
# phi_last = data['φ_time_series'][-1]
# Create rectangular mesh
mesh = RectangleMesh(Point(0.0, 0.0), Point(W, H), nx, ny)

# %%
φ_o = 1.0       # initial polymer volume fraction
φ_swell = 0.35  # volumen fraction when the gel is swollen

# %%
# Form compiler options
parameters["form_compiler"]["optimize"]     = True
parameters["form_compiler"]["cpp_optimize"] = True

# %%
### Field variable function spaces
element_u = VectorElement('CG', mesh.ufl_cell(), 2) # displacement finite element
element_phi = FiniteElement('CG', mesh.ufl_cell(), 1) # chemical potential finite element
# W = FunctionSpace(mesh, MixedElement([element_u, element_mu]))
V, Q = FunctionSpace(mesh, element_u), FunctionSpace(mesh, element_phi)

# %%
# Define boundary conditions
class Left(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[0], 0)
class Right(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[0], L)
class Top(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[1], L)
class Bottom(SubDomain):
    def inside(self,x, on_boundary):
        return on_boundary and near(x[1], 0)

# Add boundaries
left = Left()
right = Right()
top = Top()
bottom = Bottom()

boundaries = MeshFunction("size_t", mesh, mesh.topology().dim()-1, 0)
left.mark(boundaries, 1)
right.mark(boundaries, 2)
top.mark(boundaries, 3)
bottom.mark(boundaries,4)

# %%
# zero displacement boundary conditions on the symmetric part of the plate
# u_bc_bottom = DirichletBC(V.sub(1), Constant(0.0), bottom) 
# u_bc_right = DirichletBC(V.sub(0), Constant(0.0), right)
u_bc_left_x = DirichletBC(V.sub(0), Constant(0.0), left)
u_bc_left_y = DirichletBC(V.sub(1), Constant(0.0), left)

# polymer volume fraction on the outer boundaries
phi_bc_top = DirichletBC(Q, Constant(φ_swell), top)
# phi_bc_left = DirichletBC(Q, Constant(φ_swell), left)
phi_bc_right = DirichletBC(Q, Constant(φ_swell), right)

# bcs = [u_bc_bottom, u_bc_right, mu_bc_bottom, mu_bc_right]
# bcs = [u_bc_bottom, u_bc_right, mu_bc_top, mu_bc_left]

# bc_u = [u_bc_bottom, u_bc_left] #u_bc_right]
# bc_phi = [phi_bc_top, phi_bc_right] #phi_bc_left]

bc_u = [u_bc_left_x, u_bc_left_y]#, u_bc_right]
bc_phi = [phi_bc_top, phi_bc_right] #phi_bc_left]

# %%
(du, dφ) = TrialFunction(V), TrialFunction(Q)
(v, q) = TestFunction(V), TestFunction(Q)

(u, φ) = Function(V), Function(Q)
(uold, φold) = Function(V), Function(Q)

# Create intial conditions and interpolate
# u_init = InitialConditions()
φ_init = Expression("0.45", degree=1)
φold.interpolate(φ_init)
φ.assign(φold)

# %%
# Model parameters
# Elasticity parameters
G0, χ = Constant(100.0e6), Constant(0.2)#Constant(0.1)
K = Constant(100.0e6)#Constant(3.93e6) # Bulk modulus
ΩK = Constant(100.0e6)
NΩ = Constant(1e-3)
Ω = Constant(1.7e-28)#Constant(1e-4)                          # the volume per solvent molecule
kBT = Constant(1.3806488e-23*298)              # T = 298 K
RT = Constant(8.31446261815324*298)
D = Constant(5e-8)#Constant(0.1)#Constant(7.4e-11)                          # species diffusivity m^2 s^-1
mc = Constant(0.1)
gamma_s = Constant(10.)

µ_o = Constant(0.0)

alpha_r = 1.0 # Robin Boundary constant

# %%
# Kinematics
d = u.geometric_dimension()
I = Identity(d)                         # Identity tensor

def F(u):
    return variable(I + grad(u)) 

# F = variable(I + grad(u))               # Deformation gradient
# C = F.T*F                             # Right Cauchy-Green tensor

# Left Cauchy-Green tensor
def B(u):
    return variable(F(u)*F(u).T)

# Invariants of deformation tensors
def Ic(u):
    return variable(tr(F(u).T*F(u)))
 
# Ic = tr(F(u).T*F(u))

def J(u):
    return variable(det(F(u)))

# J  = (det(F)) #1 + Ω*C

# %%
# Cauchy stress
def T_(u,φ):
    return variable(inv(J(u))*(G0*(B(u) - (φ**(-2))*I)))# + (1/φ)*K*ln(J(u)*φ)*I))

# Piola stress - P = JTF^-T
def PK1(u,φ):
    # return variable(G0*(B(u) - (φ**(-2))*I)*inv(F(u).T)) # <= as in Chester et al. 2010
    return variable((G0*(B(u) - I) + K*(ln(J(u)*0.999*φ))*I)*inv(F(u).T))         # <= as in Chester et al. 2011
    # return variable((G0*(B(u) - I) + (1/φ)*K*ln(J(u)*φ)*I)*inv(F(u).T))         # <= as in Chester et al. 2015

# Chemical potential - µ
def µ_(u,φ):
    # return variable(µ_o + kBT*(ln(1 - 0.999*φ) + φ + χ*(φ**2)) + (Ω*G0)*(0.999/φ - 0.999*φ)) # <= as in Chester et al. 2010
    return variable((µ_o) + RT*(ln(1 - 0.999*φ) + φ + χ*(φ**2)) - (Ω*K)*ln(J(u)*φ)*φ) # <= as in Chester et al. 2011
    # return variable((µ_o) + RT*(ln(1 - 0.999*φ) + φ + χ*(φ**2)) - (Ω*K)*ln(J(u)) + (1/2)*(Ω*K)*ln(J(u)*0.999*φ)**2)  # <= as in Chester et al. 2015

# %%
ds = Measure('ds', domain=mesh, subdomain_data=boundaries)
dt = Constant(0.)

# Forces balance
Pi_mech_n = inner(PK1(u,φ), grad(v))*dx
Jac_n = derivative(Pi_mech_n, u, du) 

# Mass balance
D = 7.5e-8*kBT # <= this values works as well for Chester et al. 2011 and matches Chester et al. 2015
alpha_r = 10 # <= this works for Chester et al. 2015 
phi_form = (((φ - φold)/dt*q
            - (D/(kBT))*(dot(grad(φ),grad(µ_(u,φ))))*q 
            - (D/(kBT))*(dot(((φ**2)*((1 - 0.999*φ)/φ))*grad(µ_(u,φ)),grad(q))))*dx
            + alpha_r*(φ - φ_swell)*q*ds(3))

Jac_phi = derivative(phi_form, φ, dφ)

# %%
# Time-stepping
Nincr = 250
# t = np.linspace(0, 50, Nincr+1)
t = np.logspace(-5, 1, Nincr+1)
Nx = 50
x = np.linspace(0, L, Nx)
µ_res = np.zeros((Nx, Nincr+1))

φ_res = np.zeros((Nx, Nincr+1))
φ_0_array = np.zeros((Nx, Nincr+1))
φ_05_array = np.zeros((Nx, Nincr+1))
φ_L_array = np.zeros((Nx, Nincr+1))

PK1_y_array = np.zeros((Nx, Nincr+1))
PK1xx0_array = np.zeros((Nx, Nincr+1))
PK1xxL_array = np.zeros((Nx, Nincr+1))

tolerance = 1e-6  # Set your own tolerance level
max_iterations = 10  # Set your own max number of iterations

for (i, dti) in enumerate(np.diff(t)):
    print("Increment " + str(i+1))
    t_current = t[i+1]
    print("t =", t_current) 
    dt.assign(dti)
    
    iteration = 0
    error = 1.0  # Initial error value
    
    while error > tolerance and iteration < max_iterations:
        iteration += 1
        
        # Save previous solutions
        u_prev = u.copy(deepcopy=True)
        φ_prev = φ.copy(deepcopy=True)
        
        # Compute tentative displacement step
        begin("Computing tentative displacement")
        solve(Pi_mech_n == 0, u, bc_u, J=Jac_n, solver_parameters={"newton_solver":
                                        {"relative_tolerance": 1e-6, "convergence_criterion": "incremental"}})
        end()
    
        # Chemical potential
        begin("Computing phi")
        solve(phi_form == 0, φ, J=Jac_phi)#bc_phi
        end()
        
        # Compute error as the maximum difference in the solutions
        error_u = np.max(np.abs(u.vector().get_local() - u_prev.vector().get_local()))
        error_φ = np.max(np.abs(φ.vector().get_local() - φ_prev.vector().get_local()))
        error = max(error_u, error_φ)
        
        print(f'Iteration: {iteration}, Error: {error}')
    
    # Store results for post-processing
    uold.assign(u)
    φold.assign(φ)
    
    φ_res[:, i+1] = [φ(L/2,xi) for xi in x]    
    φ_0_array[:, i+1] = [φ(0.0, xi) for xi in x]
    φ_05_array[:, i+1] = [φ(L/2, xi) for xi in x]
    φ_L_array[:, i+1] = [φ(L, xi) for xi in x]
    
    mu_y = µ_(u,φ)
    mu_y_P1 = project(mu_y/kBT, Q)
    µ_res[:, i+1] = [mu_y_P1(L/2, xi) for xi in x]
    
    sigma_y = PK1(u,φ)[1,1]
    sigma_y_P1 = project(sigma_y, Q)
    PK1_y_array[:, i+1] = [sigma_y_P1(L/2, xi) for xi in x]
    
    PK1xx = PK1(u,φ)[0,0]
    PK1xx_P1 = project(PK1xx, Q)
    PK1xx0_array[:, i+1] = [PK1xx_P1(0.0, xi) for xi in x] 
    PK1xxL_array[:, i+1] = [PK1xx_P1(L, xi) for xi in x]    
    print("t =", dti)
    
    if i == 208 or i == 227 or i == 237 or i == 249:
        plt.figure()
        p = plot(φ, title="Polymer volume fraction")
        plt.colorbar(p)
        plt.close()
        
        
        plt.figure(figsize=(6,5))
        p = plot(u, mode="displacement")
        plt.xlim((-0.0005, 0.017))
        plt.ylim((-0.0005, 0.017))
        # plt.axvline(x = 0.5, color = 'k', linestyle = '--', label = 'axvline - full height')
        plot(mesh, linewidth=1.0)
        # cbar = plt.colorbar(p, format="%.2f")#, shrink = 0.5)
        # cbar.ax.tick_params(labelsize=14)
        plt.tick_params(axis='both', labelsize=18)
        plt.xlabel("$X$-coord. [m]", fontsize=18)
        plt.ylabel("$Y$-coord. [m]", fontsize=18)
        # plt.legend(["deformed gel"])
        plt.title("deformed gel ($t = {:.1f}$ [s])".format(t_current), fontsize = 16)
        # plt.savefig('results/Chester/time/Fig_2DFEM_def_gel_x001_{:.1f}_2011_v2.pdf'.format(t_current))
        # plt.savefig('results/Chester/time/Fig_2DFEM_def_gel_x001_{:.1f}_2015_v2.pdf'.format(t_current))
        plt.close() 

        plt.figure(figsize=(6,5))
        p = plot(PK1(u,φ)[0,0], title="$sigma_{xx}$ nominal stress")
        cbar = plt.colorbar(p)#, shrink = 0.5)
        cbar.ax.tick_params(labelsize=14)
        plt.tick_params(axis='both', labelsize=16)
        plt.xlabel("$X$-coordinate", fontsize=16)
        plt.ylabel("$Y$-coordinate", fontsize=16)
        plt.title("stress $PK1_{xx}$", fontsize = 18)
        # plt.savefig('results/Chester/Fig_2DFEM_stress_{:.1f}.pdf'.format(t_current))
        plt.close()
        
    print("t =", dti)
# Out:
# Increment 1
# t = 1.0568175092136585e-05
#                 Computing tentative displacement
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.287e-01 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.543e-02 (tol = 1.000e-10) r (rel) = 1.986e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.187e-02 (tol = 1.000e-10) r (rel) = 5.191e-02 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 8.698e-04 (tol = 1.000e-10) r (rel) = 3.803e-03 (tol = 1.000e-06)
#                     Newton iteration 4: r (abs) = 1.720e-04 (tol = 1.000e-10) r (rel) = 7.520e-04 (tol = 1.000e-06)
#                     Newton iteration 5: r (abs) = 4.016e-08 (tol = 1.000e-10) r (rel) = 1.756e-07 (tol = 1.000e-06)
#                     Newton solver finished in 6 iterations and 6 linear solver iterations.
#                 Computing phi
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.766e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.127e-08 (tol = 1.000e-10) r (rel) = 6.383e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 1.050e-15 (tol = 1.000e-10) r (rel) = 5.944e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.01597545406712603
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.239e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 1.976e-05 (tol = 1.000e-10) r (rel) = 2.398e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 6.790e-09 (tol = 1.000e-10) r (rel) = 8.242e-06 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.301e-15 (tol = 1.000e-10) r (rel) = 1.579e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.050e-15 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 6.0114587460055645e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.516e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 3.469446951953614e-18
# t = 5.681750921365838e-07
# t = 5.681750921365838e-07
# Increment 2
# t = 1.1168632477805611e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.050e-15 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.189e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.732e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.193e-08 (tol = 1.000e-10) r (rel) = 6.890e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 1.038e-15 (tol = 1.000e-10) r (rel) = 5.995e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.0029476368252919216
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.572e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.138e-05 (tol = 1.000e-10) r (rel) = 2.494e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 7.957e-09 (tol = 1.000e-10) r (rel) = 9.283e-06 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.474e-15 (tol = 1.000e-10) r (rel) = 1.720e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.038e-15 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 6.250012760687781e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.746e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.038e-15 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 1.2793585635328952e-17
# t = 6.004573856690268e-07
# t = 6.004573856690268e-07
# Increment 3
# t = 1.1803206356517298e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.764e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.696e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.260e-08 (tol = 1.000e-10) r (rel) = 7.425e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 9.378e-16 (tol = 1.000e-10) r (rel) = 5.528e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.0030204115816686583
#                 Computing tentative displacement
# Iteration: 2, Error: 6.491449577918518e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.909e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.309e-05 (tol = 1.000e-10) r (rel) = 2.592e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 9.287e-09 (tol = 1.000e-10) r (rel) = 1.042e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 2.196e-15 (tol = 1.000e-10) r (rel) = 2.465e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.378e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variationIteration: 3, Error: 5.421010862427522e-18
# t = 6.345738787116865e-07
# t = 6.345738787116865e-07
# Increment 4
# t = 1.2473835142429432e-05
# al problem.
#                     Newton iteration 0: r (abs) = 6.956e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.378e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.577e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.660e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.326e-08 (tol = 1.000e-10) r (rel) = 7.989e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 8.892e-16 (tol = 1.000e-10) r (rel) = 5.358e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.0030895512485604737
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.250e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.488e-05 (tol = 1.000e-10) r (rel) = 2.690e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.079e-08 (tol = 1.000e-10) r (rel) = 1.167e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 2.988e-15 (tol = 1.000e-10) r (rel) = 3.230e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Iteration: 2, Error: 6.734943992277933e-05
# Iteration: 3, Error: 7.15573433840433e-18                Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.892e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.597e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.892e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#
# t = 6.706287859121339e-07
# t = 6.706287859121339e-07
# Increment 5
# t = 1.3182567385564074e-05
#                 Computing tentative displacement
# Iteration: 1, Error: 0.0031544092913743382
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.396e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.622e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.391e-08 (tol = 1.000e-10) r (rel) = 8.580e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 8.079e-16 (tol = 1.000e-10) r (rel) = 4.982e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 2, Error: 6.979555353155202e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.592e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.675e-05 (tol = 1.000e-10) r (rel) = 2.789e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.249e-08 (tol = 1.000e-10) r (rel) = 1.302e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 3.788e-15 (tol = 1.000e-10) r (rel) = 3.949e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.079e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.114e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.079e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 2.7430314963883262e-17
# t = 7.087322431346425e-07
# t = 7.087322431346425e-07
# Increment 6
# t = 1.3931568029453036e-05
#                 Computing tentative displacement
# Iteration: 1, Error: 0.0032143095644995845
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.416e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.582e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.456e-08 (tol = 1.000e-10) r (rel) = 9.198e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 7.961e-16 (tol = 1.000e-10) r (rel) = 5.031e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.936e-04 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.869e-05 (tol = 1.000e-10) r (rel) = 2.888e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.438e-08 (tol = 1.000e-10) r (rel) = 1.447e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 5.155e-15 (tol = 1.000e-10) r (rel) = 5.189e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.961e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 7.224220986282322e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.316e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 6.938893903907228e-18
# t = 7.490006438889618e-07
# t = 7.490006438889618e-07
# Increment 7
# t = 1.4723125024327194e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.961e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.251e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.542e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.518e-08 (tol = 1.000e-10) r (rel) = 9.842e-07 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 7.052e-16 (tol = 1.000e-Iteration: 1, Error: 0.003268551085375604
# 10) r (rel) = 4.573e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.028e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.070e-05 (tol = 1.000e-10) r (rel) = 2.987e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.647e-08 (tol = 1.000e-10) r (rel) = 1.603e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 6.764e-15 (tol = 1.000e-10) r (rel) = 6.582e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.052e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#    Iteration: 2, Error: 7.467750415855607e-05
#                  Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.812e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 8.239936510889834e-18
# t = 7.915569948741581e-07
# t = 7.915569948741581e-07
# Increment 8
# t = 1.555965631605075e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.052e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.890e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.501e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.577e-08 (tol = 1.000e-10) r (rel) = 1.051e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 6.371e-16 (tol = 1.000e-10) r (rel) = 4.246e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.003316414003506185
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.062e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.275e-05 (tol = 1.000e-10) r (rel) = 3.085e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.876e-08 (tol = 1.000e-10) r (rel) = 1.768e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 8.983e-15 (tol = 1.000e-10) r (rel) = 8.462e-12 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.371e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 7.708820696032266e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.835e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.371e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 5.990217002982412e-18
# t = 8.365312917235555e-07
# t = 8.365312917235555e-07
# Increment 9
# t = 1.6443717232149325e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.230e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.458e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.633e-08 (tol = 1.000e-10) r (rel) = 1.120e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 5.818e-16 (tol = 1.000e-10) r (rel) = 3.990e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.0033571668522101583
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.095e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.484e-05 (tol = 1.000e-10) r (rel) = 3.182e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 2.125e-08 (tol = 1.000e-10) r (rel) = 1.941e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.146e-14 (tol = 1.000e-10) r (rel) = 1.046e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Iteration: 2, Error: 7.94597320234828e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.818e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.571e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.818e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 6.776263578034403e-18
# t = 8.84060916098575e-07
# t = 8.84060916098575e-07
# Increment 10
# t = 1.7378008287493764e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.217e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0033900751528827544
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.414e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.685e-08 (tol = 1.000e-10) r (rel) = 1.191e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 6.093e-16 (tol = 1.000e-10) r (rel) = 4.308e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.127e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.695e-05 (tol = 1.000e-10) r (rel) = 3.277e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 2.392e-08 (tol = 1.000e-10) r (rel) = 2.121e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.432e-14 (tol = 1.000e-10) r (rel) = 1.270e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.093e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 8.177612277921873e-05
#                 Computing tentative displacement
# Iteration: 3, Error: 6.5052130349130266e-18
# t = 9.342910553444391e-07
# t = 9.342910553444391e-07
# Increment 11
# t = 1.8365383433483475e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.257e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.093e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.415e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0034144114166376194
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.370e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.732e-08 (tol = 1.000e-10) r (rel) = 1.264e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 5.611e-16 (tol = 1.000e-10) r (rel) = 4.096e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.159e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.906e-05 (tol = 1.000e-10) r (rel) = 3.370e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 2.674e-08 (tol = 1.000e-10) r (rel) = 2.307e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.794e-14 (tol = 1.000e-10) r (rel) = 1.548e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.611e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 8.402006171571847e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.153e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.611e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 6.071532165918825e-18
# t = 9.873751459897114e-07
# t = 9.873751459897114e-07
# Increment 12
# t = 1.9408858775927792e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.658e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0034294665555894555
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.324e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.773e-08 (tol = 1.000e-10) r (rel) = 1.339e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 5.426e-16 (tol = 1.000e-10) r (rel) = 4.097e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.189e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.114e-05 (tol = 1.000e-10) r (rel) = 3.459e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 2.969e-08 (tol = 1.000e-10) r (rel) = 2.496e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 2.205e-14 (tol = 1.000e-10) r (rel) = 1.854e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
# Iteration: 2, Error: 8.61729074179272e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.426e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.330e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.426e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 8.998878031629687e-18
# t = 1.043475342444317e-06
# t = 1.043475342444317e-06
# Increment 13
# t = 2.0511621788255667e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.962e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.278e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.807e-08 (tol = 1.000e-10) r (rel) = 1.414e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 5.002e-16 (tol = 1.000e-10) r (rel) = 3.914e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.0034345626750421077
#                 Computing tentative displacement
# Iteration: 2, Error: 8.821476428822581e-05
# Iteration: 3, Error: 6.071532165918825e-18
# t = 1.1027630123278745e-06
# t = 1.1027630123278745e-06
# Increment 14
# t = 2.1677041048196962e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.218e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.317e-05 (tol = 1.000e-10) r (rel) = 3.544e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 3.271e-08 (tol = 1.000e-10) r (rel) = 2.686e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 2.665e-14 (tol = 1.000e-10) r (rel) = 2.188e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.002e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.526e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.002e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.187e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.230e-02 (tol = 1.000e-10) r (rel) =Iteration: 1, Error: 0.003429067168032096
# Iteration: 2, Error: 9.012459012376292e-05
#  1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.833e-08 (tol = 1.000e-10) r (rel) = 1.490e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 4.939e-16 (tol = 1.000e-10) r (rel) = 4.014e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.245e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.512e-05 (tol = 1.000e-10) r (rel) = 3.625e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 3.575e-08 (tol = 1.000e-10) r (rel) = 2.872e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 3.177e-14 (tol = 1.000e-10) r (rel) = 2.552e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solverIteration: 3, Error: 8.023096076392733e-18
# t = 1.1654192599412954e-06
# t = 1.1654192599412954e-06
# Increment 15
# t = 2.290867652767775e-05
#  iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.939e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.796e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.939e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.002e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.182e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.852e-08 (tol = 1.000e-10) r (rel) = 1.566e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 4.727e-16 (tol = 1.000e-Iteration: 1, Error: 0.003412407974940135
# 10) r (rel) = 3.998e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.269e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.697e-05 (tol = 1.000e-10) r (rel) = 3.700e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 3.875e-08 (tol = 1.000e-10) r (rel) = 3.052e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 3.729e-14 (tol = 1.000e-10) r (rel) = 2.938e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Iteration: 2, Error: 9.188034670304867e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.727e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.486e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.727e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 4.336808689942018e-18
# t = 1.2316354794807867e-06
# t = 1.2316354794807867e-06
# Increment 16
# t = 2.42102904673618e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.455e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.134e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.862e-08 (tol = 1.000e-10) r (rel) = 1.642e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 4.830e-16 (tol = 1.000e-10) r (rel) = 4.260e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.003384089803573631
#                 Computing tentative displacement
# Iteration: 2, Error: 9.345919827756299e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.292e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.867e-05 (tol = 1.000e-10) r (rel) = 3.768e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 4.161e-08 (tol = 1.000e-10) r (rel) = 3.222e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 4.286e-14 (tol = 1.000e-10) r (rel) = 3.319e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.830e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variationIteration: 3, Error: 1.5937771935536915e-17
# t = 1.3016139396840505e-06
# t = 1.3016139396840505e-06
# Increment 17
# t = 2.558585886905648e-05
# al problem.
#                     Newton iteration 0: r (abs) = 1.875e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.830e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.760e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.085e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.862e-08 (tol = 1.000e-10) r (rel) = 1.717e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 3.993e-16 (tol = 1.000e-10) r (rel) = 3.681e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.003343711030196761
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.311e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 5.019e-05 (tol = 1.000e-10) r (rel) = 3.829e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 4.425e-08 (tol = 1.000e-10) r (rel) = 3.376e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 4.886e-14 (tol = 1.000e-10) r (rel) = 3.728e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Iteration: 2, Error: 9.483809618778113e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.993e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.739e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 7.48099499014998e-18
# t = 1.3755684016946789e-06
# t = 1.3755684016946789e-06
# Increment 18
# t = 2.703958364108846e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.993e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.553e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.035e-02 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.852e-08 (tol = 1.000e-10) r (rel) = 1.790e-06 (tol = 1.000e-09)
#                     Newton iteration 2: r (abs) = 3.890e-16 (tol = 1.000e-10) r (rel) = 3.758e-14 (tol = 1.000e-09)
#                     Newton solver finished in 2 iterations and 2 linear solver iterations.
# Iteration: 1, Error: 0.003290980921075326
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.327e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 5.149e-05 (tol = 1.000e-10) r (rel) = 3.881e-02 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 4.659e-08 (tol = 1.000e-10) r (rel) = 3.511e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 5.380e-14 (tol = 1.000e-10) r (rel) = 4.055e-11 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
# Iteration: 2, Error: 9.599748483236881e-05
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.890e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.312e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.890e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 1.5178830414797062e-17
# t = 1.453724772031983e-06
# t = 1.453724772031983e-06
# Increment 19
# t = 2.8575905433749495e-05
#                 Computing tentative displacement
# ...
#                     Newton iteration 0: r (abs) = 4.853e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.256e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 1.3227266504323154e-17
# t = 0.3859065865417719
# t = 0.3859065865417719
# Increment 245
# t = 7.585775750291836
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.853e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.060e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.696e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 3.914e-11 (tol = 1.000e-10) r (rel) = 5.086e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0007054112113415445
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.789e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 5.990e-04 (tol = 1.000e-10) r (rel) = 2.148e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.991e-06 (tol = 1.000e-10) r (rel) = 7.140e-04 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 2.720e-10 (tol = 1.000e-10) r (rel) = 9.754e-08 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.914e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 0.00016152294497702777
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.614e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 7.37257477290143e-18
# t = 0.407832837578221
# t = 0.407832837578221
# Increment 246
# t = 8.01678063387679
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.914e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.267e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 6.546e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 3.110e-11 (tol = 1.000e-10) r (rel) = 4.751e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0006298183483777753
# Iteration: 2, Error: 0.00014448103511724382
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.425e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 4.661e-04 (tol = 1.000e-10) r (rel) = 1.922e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.176e-06 (tol = 1.000e-10) r (rel) = 4.849e-04 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 9.730e-11 (tol = 1.000e-10) r (rel) = 4.012e-08 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.110e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 1.6046192152785466e-17
# t = 0.43100488358495426
# t = 0.43100488358495426
# Increment 247
# t = 8.472274141405963
# Iteration: 1, Error: 0.000557844538896457
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.000e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.110e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 8.540e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 5.527e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 2.433e-11 (tol = 1.000e-10) r (rel) = 4.402e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.096e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 3.574e-04 (tol = 1.000e-10) r (rel) = 1.705e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 6.758e-07 (tol = 1.000e-10) r (rel) = 3.224e-04 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 3.290e-11 (tol = 1.000e-10) r (rel) = 1.570e-08 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.433e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 0.0001281774065744393
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.031e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 2.433e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 3.903127820947816e-18
# t = 0.45549350752917306
# t = 0.45549350752917306
# Increment 248
# t = 8.953647655495937
#                 Computing tentative displacement
# Iteration: 1, Error: 0.0004899415920311956
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 7.514e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.629e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.872e-11 (tol = 1.000e-10) r (rel) = 4.043e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.799e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.699e-04 (tol = 1.000e-10) r (rel) = 1.500e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 3.773e-07 (tol = 1.000e-10) r (rel) = 2.097e-04 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 1.048e-11 (tol = 1.000e-10) r (rel) = 5.824e-09 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.872e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 0.00011273281203937757
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.999e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 3, Error: 6.938893903907228e-18
# t = 0.48137351408997375
# t = 0.48137351408997375
# Increment 249
# t = 9.462371613657929
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.872e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.275e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.844e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.415e-11 (tol = 1.000e-10) r (rel) = 3.680e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0004264898177454568
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.534e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 2.006e-04 (tol = 1.000e-10) r (rel) = 1.307e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 2.043e-07 (tol = 1.000e-10) r (rel) = 1.332e-04 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 3.135e-12 (tol = 1.000e-10) r (rel) = 2.044e-09 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
# Iteration: 2, Error: 9.825022962748134e-05
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.415e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 4.995e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.415e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 5.204170427930421e-18
# t = 0.5087239581619922
# t = 0.5087239581619922
# Increment 250
# t = 10.0
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 9.698e-17 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 3.165e-08 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton iteration 1: r (abs) = 1.050e-11 (tol = 1.000e-10) r (rel) = 3.317e-04 (tol = 1.000e-09)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
# Iteration: 1, Error: 0.0003677886419262699
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.298e-03 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton iteration 1: r (abs) = 1.465e-04 (tol = 1.000e-10) r (rel) = 1.129e-01 (tol = 1.000e-06)
#                     Newton iteration 2: r (abs) = 1.071e-07 (tol = 1.000e-10) r (rel) = 8.254e-05 (tol = 1.000e-06)
#                     Newton iteration 3: r (abs) = 8.776e-13 (tol = 1.000e-10) r (rel) = 6.761e-10 (tol = 1.000e-06)
#                     Newton solver finished in 4 iterations and 4 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.050e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 2, Error: 8.481246611209204e-05
#                 Computing tentative displacement
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.842e-16 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-06)
#                     Newton solver finished in 1 iterations and 1 linear solver iterations.
#                 Computing phi
#                   Solving nonlinear variational problem.
#                     Newton iteration 0: r (abs) = 1.050e-11 (tol = 1.000e-10) r (rel) = 1.000e+00 (tol = 1.000e-09)
#                     Newton solver finished in 0 iterations and 0 linear solver iterations.
# Iteration: 3, Error: 1.3010426069826053e-17
# t = 0.537628386342071
#                 Object cannot be plotted directly, projecting to piecewise linears.
# t = 0.537628386342071

# %%
plt.figure(figsize=(6,5))
p = plot(u, mode="displacement")
plt.xlim((-0.0005, 0.09))
plt.ylim((-0.001, 0.02))
plot(mesh, linewidth=1.0)
# cbar = plt.colorbar(p, format="%.2f")#, shrink = 0.5)
# cbar.ax.tick_params(labelsize=14)
plt.tick_params(axis='both', labelsize=16)
plt.xlabel("$X$-coord. [m]", fontsize=16)
plt.ylabel("$Y$-coord. [m]", fontsize=16)
# plt.legend(["deformed gel"])
plt.title("deformed gel ($t = {:.1f}$ [s])".format(t_current), fontsize = 16)
# plt.savefig('results/Chester/time/Fig_2DFEM_def_gel_x001_bech_{:.1f}_2011.pdf'.format(t_current))
# plt.savefig('results/Chester/time/Fig_2DFEM_def_gel_x001_bech_{:.1f}_2015.pdf'.format(t_current))
plt.show()

# %%
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1 import make_axes_locatable
from labellines import labelLine, labelLines

# stretch
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[0]

nValues = np.arange(0,4)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis
i = 0
for n in [208,227,237,249]:
    # ax.plot(x, lambda_res[:, n+1], 'k.')
    ax.plot(x, φ_res[:, n+1], color=colormap(normalize(i)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))
    i = i+1

labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=14)
ax.set_xlabel("$Y$-coord. along $X=0.005$ [m]", fontsize=18)
ax.set_ylabel("polymer volume fraction $\phi$", fontsize=18)
# ax.legend(["reference 1D sol.", "2D FEM approx."], fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda Jx_array, pos: "{:.2f}".format(Jx_array)))

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Chester/Fig_2DFEM_phi_time_2011_x001_v2.pdf')
# plt.savefig('results/Chester/Fig_2DFEM_phi_time_2015_x001_v2.pdf')

# stretch
fig, ax = plt.subplots(figsize=(6,5))

normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

ax.plot(t[1:], φ_0_array[0, 1:], color=colormap(normalize(0)), label="a")
ax.plot(t[1:], φ_05_array[24, 1:], color=colormap(normalize(2)), label="b")
ax.plot(t[1:], φ_L_array[-1, 1:], color=colormap(normalize(3)), label="c")

# xvals = [0.2, 0.2, 0.2]
# labelLines(ax.get_lines(), align=False, xvals=xvals, color="k", fontsize=14)
labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=14)
ax.set_xlabel("time [s]", fontsize=18)
ax.set_ylabel("$\phi$ at different corners", fontsize=18)
# ax.legend(["bottom-left edge", "bottom-right edge", "top-left edge"], fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=16)

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Chester/Fig_2DFEM_phi_2011_x001_v2.pdf')
# plt.savefig('results/Chester/Fig_2DFEM_phi_2015_x001_v2.pdf')

# stress
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[2]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

print(PK1xxL_array.size)

ax.plot(t[1:], PK1xx0_array[0, 1:], color=colormap(normalize(0)), label="a")
ax.plot(t[1:], PK1xx0_array[-1, 1:], color=colormap(normalize(7)), label="b")
ax.plot(t[1:], PK1xxL_array[-1, 1:], color=colormap(normalize(3)), label="c")

xvals = [0.12, 0.12, 0.12]
# xvals = [0.2, 0.2, 0.2]
labelLines(ax.get_lines(), align=False, xvals=xvals, color="k", fontsize=14)
ax.set_xlabel("time [s]", fontsize=18)
# ax.set_ylabel("normalized stress at different edges \n $PK1_{xx}/Nk_B T$ [MPa/MPa]", fontsize=14)
ax.set_ylabel("compressive stress \n $PK1_{xx}$ [Pa]", fontsize=18)
# ax.legend(["reference 1D sol.", "2D FEM approx."])
ax.tick_params(axis='both', which='major', labelsize=16)

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Chester/Fig_2DFEM_PK1_2011_x001.pdf')
# plt.savefig('results/Chester/Fig_2DFEM_PK1_2015_x001.pdf')
plt.show()

# chemical potential
fig, ax = plt.subplots()

nValues = np.arange(0,200)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

for n in [150,180,190,199]:
    ax.plot(x, (1.3806488e-23*298)*µ_res[:, n+1], color=colormap(normalize(n)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))

labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=8)
ax.set_xlabel("$Y$-coordinate along $X=1.0$", fontsize=14)
ax.set_ylabel("normalized chemical potential \n $\mu/k_B T$ [mol$^{-1}$]", fontsize=14)
# ax.legend(["reference 1D sol.", "2D FEM approx."])
ax.tick_params(axis='both', which='major', labelsize=14)
# Out:
# 12550

# %%
# stretch
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[0]

nValues = np.arange(0,4)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis
i = 0
for n in [208,227,237,249]:
    ax.plot(x, 1/φ_res[:, n+1], color=colormap(normalize(i)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))
    i = i + 1

labelLines(ax.get_lines(), align=False, zorder=2.5, color="k", fontsize=14)
ax.set_xlabel("$Y$-coord. along $X=0.005$ [m]", fontsize=18)
ax.set_ylabel("stretch $\lambda$", fontsize=18)
# ax.legend(["reference 1D sol.", "2D FEM approx."], fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=16)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda Jx_array, pos: "{:.2f}".format(Jx_array)))

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Chester/Fig_2DFEM_stretch_time_2011_x001_bench_v2.pdf')
# plt.savefig('results/Chester/Fig_2DFEM_stretch_time_2015_x001_bench_v2.pdf')

# stretch
fig, ax = plt.subplots(figsize=(6,5))
# ax = axes[1]

nValues = np.arange(0,10)
# setup the normalization and the colormap
normalize = mcolors.Normalize(vmin=nValues.min(), vmax=nValues.max())
colormap = cm.viridis

ax.plot(t[1:], 1/φ_0_array[0, 1:], color=colormap(normalize(0)), label="a")
ax.plot(t[1:], 1/φ_05_array[24, 1:], color=colormap(normalize(3)), label="b")
ax.plot(t[1:], 1/φ_L_array[-1, 1:], color=colormap(normalize(7)), label="c")

# for n in nValues:
#     ax.plot(t[1:], lambda_array[n+1, 1:], color=colormap(normalize(n)), label="$t = {:.1f}$".format(t[n+1]))#, label=str(t[n]))

xvals = [0.2, 0.2, 0.2]
labelLines(ax.get_lines(), align=False, xvals=xvals, color="k", fontsize=14)
ax.set_xlabel("time [s]", fontsize=18)
ax.set_ylabel("$\lambda$ at different corners", fontsize=18)
# ax.legend(["bottom-left edge", "bottom-right edge", "top-left edge"], fontsize=14)
ax.tick_params(axis='both', which='major', labelsize=16)

# Adjust the margins
plt.subplots_adjust(left=0.15, bottom=0.15, right=0.95, top=0.95)

# plt.savefig('results/Chester/Fig_2DFEM_stretch_2011_x001_bench_v2.pdf')
# plt.savefig('results/Chester/Fig_2DFEM_stretch_2015_x001_bench_v2.pdf')
